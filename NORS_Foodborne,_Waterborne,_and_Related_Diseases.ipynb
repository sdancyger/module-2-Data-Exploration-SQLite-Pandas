# %% [markdown]
# <a href="https://colab.research.google.com/github/sdancyger/sqlite_dataexploration/blob/main/NORS_Foodborne%2C_Waterborne%2C_and_Related_Diseases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## NORS Foodborne, Waterborne, and Related Diseases

# %% [markdown]
# ### Data Provided By: Centers for Disease Control and Prevention

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0bb9ccc0-febc-4a43-8e1a-40c3588d9a13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0bb9ccc0-febc-4a43-8e1a-40c3588d9a13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install sqlite3
# Out:
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
import pandas as pd
import sqlite3

# %%
import sqlite3

# %% [markdown]
# load data from excel file

# %%
df = pd.read_excel('NORS_20241006.xlsx')

# %%
conn = sqlite3.connect('healthcare.db')

# %%
df.to_sql('healthcare_data', conn, if_exists='replace', index=False)
# Out:
# 62416

# %%
conn.close()

# %%
conn = sqlite3.connect('healthcare.db')

# %%
query = pd.read_sql_query("SELECT * FROM healthcare_data LIMIT 5", conn)
print(query)
# Out:
#   NORS_20241006 Unnamed: 1    Unnamed: 2        Unnamed: 3         Unnamed: 4  \
# 0          Year      Month         State      Primary Mode           Etiology
# 1          2009          1        Alaska  Person-to-person  Norovirus unknown
# 2          2009          1          Iowa  Person-to-person  Norovirus unknown
# 3          2009         10        Kansas              Food  Norovirus unknown
# 4          2009          1  North Dakota  Person-to-person               None
#
#              Unnamed: 5       Unnamed: 6  \
# 0  Serotype or Genotype  Etiology Status
# 1                  None        Confirmed
# 2                  None        Confirmed
# 3                  None        Suspected
# 4                  None             None
#
#                                           Unnamed: 7 Unnamed: 8  \
# 0                                            Setting  Illnesses
# 1                                               None          6
# ...

# %%
df = pd.read_excel('NORS_20241006.xlsx')

# %%
df.head()
# Out:
#   NORS_20241006 Unnamed: 1    Unnamed: 2        Unnamed: 3         Unnamed: 4  \
# 0          Year      Month         State      Primary Mode           Etiology
# 1          2009          1        Alaska  Person-to-person  Norovirus unknown
# 2          2009          1          Iowa  Person-to-person  Norovirus unknown
# 3          2009         10        Kansas              Food  Norovirus unknown
# 4          2009          1  North Dakota  Person-to-person                NaN
#
#              Unnamed: 5       Unnamed: 6  \
# 0  Serotype or Genotype  Etiology Status
# 1                   NaN        Confirmed
# 2                   NaN        Confirmed
# 3                   NaN        Suspected
# 4                   NaN              NaN
#
#                                           Unnamed: 7 Unnamed: 8  \
# 0                                            Setting  Illnesses
# 1                                                NaN          6
# ...
